# %%
import pandas as pd
import numpy as np

# %%
import os
from glob import glob
all_csvs = []
file_count = 1
EXT = 'L2_options_*.csv'
while file_count <= 13:
    PATH = "C://Users/Qurram zaheer/Workstation/finalyear/{}".format(file_count)
    all_csv_files = [file
                 for path, subdir, files in os.walk(PATH)
                 for file in glob(os.path.join(path, EXT))]
    all_csvs.append(all_csv_files)
    file_count += 1

# %%
chunk1_arr = []
for month_wise in all_csvs:
    for day_csv in month_wise:
        tdf = pd.read_csv(day_csv)
        tdf = tdf[tdf['UnderlyingSymbol'] == 'SPY']
        for index, row in tdf.iterrows():
            chunk1_arr.append(row)
        print('Done')
# Out:
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# ...

# %%
chunk1 = pd.DataFrame(chunk1_arr)

# %%
chunk1.head(20)
# Out:
#        UnderlyingSymbol  UnderlyingPrice Exchange        OptionSymbol  \
# 741721              SPY           324.12        *  SPY200203C00270000
# 741722              SPY           324.12        *  SPY200203P00270000
# 741723              SPY           324.12        *  SPY200203C00275000
# 741724              SPY           324.12        *  SPY200203P00275000
# 741725              SPY           324.12        *  SPY200203C00280000
# 741726              SPY           324.12        *  SPY200203P00280000
# 741727              SPY           324.12        *  SPY200203C00285000
# 741728              SPY           324.12        *  SPY200203P00285000
# 741729              SPY           324.12        *  SPY200203C00290000
# 741730              SPY           324.12        *  SPY200203P00290000
# 741731              SPY           324.12        *  SPY200203C00291000
# 741732              SPY           324.12        *  SPY200203P00291000
# ...

# %%
chunk1.shape
# Out:
# (2560346, 20)

# %%
file_count = 1
ar2 = []
EXT2 = 'L2_optionstats*.csv'
print(EXT2)
while file_count <= 13:
    PATH = "C://Users/Qurram zaheer/Workstation/finalyear/{}".format(file_count)
    all_csv_files = [file
                 for path, subdir, files in os.walk(PATH)
                 for file in glob(os.path.join(path, EXT2))]
    print('csvs ready')
    for csv_f in all_csv_files:
        if file_count == 13:
            tdf = pd.read_csv(csv_f, names=['symbol', 'quotedate', 'iv30call', 'iv30put', 'iv30mean', 'callvol', 'putvol', 'totalvol', 'calloi', 'putoi', 'comment'])
        else:
            tdf = pd.read_csv(csv_f)
        tdf = tdf[tdf['symbol'] == 'SPY']
        for index, row in tdf.iterrows():
            ar2.append(row)
    print(file_count)
    file_count += 1
# Out:
# L2_optionstats*.csv
# csvs ready
# 1
# csvs ready
# 2
# csvs ready
# 3
# csvs ready
# 4
# csvs ready
# 5
# csvs ready
# 6
# csvs ready
# 7
# csvs ready
# 8
# csvs ready
# 9
# csvs ready
# 10
# csvs ready
# 11
# csvs ready
# 12
# csvs ready
# 13

# %%
file_count = 1
ar3 = []
EXT2 = 'L2_stock*.csv'
while file_count <= 13:
    PATH = "C://Users/Qurram zaheer/Workstation/finalyear/{}".format(file_count)
    print('csvs ready')
    all_csv_files = [file
                 for path, subdir, files in os.walk(PATH)
                 for file in glob(os.path.join(path, EXT2))]
    for csv_f in all_csv_files:
        tdf = pd.read_csv(csv_f)
        tdf = tdf[tdf['symbol'] == 'SPY']
        for index, row in tdf.iterrows():
            ar3.append(row)
    print(file_count)
    file_count += 1
# Out:
# csvs ready
# 1
# csvs ready
# 2
# csvs ready
# 3
# csvs ready
# 4
# csvs ready
# 5
# csvs ready
# 6
# csvs ready
# 7
# csvs ready
# 8
# csvs ready
# 9
# csvs ready
# 10
# csvs ready
# 11
# csvs ready
# 12
# csvs ready
# 13

# %%
chunk1.to_csv('spy_data.csv')

# %%
stats_df = pd.DataFrame(ar2)
stock_df = pd.DataFrame(ar3)
stats_df.to_csv('phase1data-stats.csv')
stock_df.to_csv('phase1data-stock.csv')

# %%
df_merged = pd.merge(stats_df, stock_df, left_on=['symbol', 'quotedate'],
              right_on=['symbol', 'quotedate'],
              how='inner')

# %%
a = '02-01-2021'
stats_df.query('quotedate == @a')
stock_df.query('quotedate == @a')
stats_df = stats_df.replace('02-01-2021', '02/01/2021')

# %%
ar2
# Out:
# [     symbol quotedate  iv30call  iv30put  iv30mean  callvol   putvol  \
#  3394    SPY  2/3/2020    0.1616   0.1649    0.1632   851840  1828476
#
#        totalvol   calloi     putoi  comment
#  3394   2680316  6418694  10882029      NaN  ,
#       symbol quotedate  iv30call  iv30put  iv30mean  callvol   putvol  \
#  3393    SPY  2/4/2020    0.1453   0.1392    0.1422   836510  1738239
#
#        totalvol   calloi     putoi  comment
#  3393   2574749  6604106  10957636      NaN  ,
#       symbol quotedate  iv30call  iv30put  iv30mean  callvol   putvol  \
#  3395    SPY  2/5/2020    0.1364    0.128    0.1322  1104236  2065727
#
#        totalvol   calloi     putoi  comment
#  3395   3169963  6685202  11123615      NaN  ,
#       symbol quotedate  iv30call  iv30put  iv30mean  callvol   putvol  \
#  3396    SPY  2/6/2020    0.1265   0.1274     0.127   863736  1355895
#
#        totalvol   calloi     putoi  comment
#  3396   2219631  6756780  11392538      NaN  ,
# ...

# %%
stats_df
# Out:
#      symbol  quotedate  iv30call  iv30put  iv30mean  callvol   putvol  \
# 3394    SPY   2/3/2020    0.1616   0.1649    0.1632   851840  1828476
# 3393    SPY   2/4/2020    0.1453   0.1392    0.1422   836510  1738239
# 3395    SPY   2/5/2020    0.1364   0.1280    0.1322  1104236  2065727
# 3396    SPY   2/6/2020    0.1265   0.1274    0.1270   863736  1355895
# 3396    SPY   2/7/2020    0.1318   0.1292    0.1305   944842  2136060
# ...     ...        ...       ...      ...       ...      ...      ...
# 3768    SPY  2/22/2021    0.1832   0.1891    0.1861  1421348  2402597
# 3781    SPY  2/23/2021    0.1794   0.1891    0.1842  1866016  2889660
# 3793    SPY  2/24/2021    0.1665   0.1730    0.1698  1779653  2525981
# 3788    SPY  2/25/2021    0.2312   0.2230    0.2271  2395911  3228557
# 3802    SPY  2/26/2021    0.2152   0.2095    0.2124  2628885  3315995
#
#       totalvol   calloi     putoi  comment
# 3394   2680316  6418694  10882029      NaN
# ...

# %%
stock_df
# Out:
#      symbol  quotedate    open      high       low   close     volume  \
# 3393    SPY   2/3/2020  323.35  326.1600  323.2200  324.12   63008919
# 3392    SPY   2/4/2020  328.07  330.0100  327.7200  329.06   56298908
# 3394    SPY   2/5/2020  332.27  333.0900  330.6700  332.84   56474640
# 3395    SPY   2/6/2020  333.91  334.1900  332.8000  333.93   45389314
# 3395    SPY   2/7/2020  332.82  333.9941  331.6000  332.24   57535098
# ...     ...        ...     ...       ...       ...     ...        ...
# 3767    SPY  2/22/2021  387.06  389.6200  386.7400  387.08   63345130
# 3771    SPY  2/23/2021  384.66  388.9450  380.2000  387.52  102931851
# 3784    SPY  2/24/2021  386.33  392.2300  385.2700  391.84   68623093
# 3787    SPY  2/25/2021  390.41  391.8800  380.7789  382.37  142434592
# 3795    SPY  2/26/2021  384.35  385.5800  378.2300  380.01  142098656
#
#       adjustedclose
# 3393         324.12
# 3392         329.06
# 3394         332.84
# 3395         333.93
# ...

# %%
df_merged
# Out:
#     symbol  quotedate  iv30call  iv30put  iv30mean  callvol   putvol  \
# 0      SPY   2/3/2020    0.1616   0.1649    0.1632   851840  1828476
# 1      SPY   2/4/2020    0.1453   0.1392    0.1422   836510  1738239
# 2      SPY   2/5/2020    0.1364   0.1280    0.1322  1104236  2065727
# 3      SPY   2/6/2020    0.1265   0.1274    0.1270   863736  1355895
# 4      SPY   2/7/2020    0.1318   0.1292    0.1305   944842  2136060
# ..     ...        ...       ...      ...       ...      ...      ...
# 264    SPY  2/22/2021    0.1832   0.1891    0.1861  1421348  2402597
# 265    SPY  2/23/2021    0.1794   0.1891    0.1842  1866016  2889660
# 266    SPY  2/24/2021    0.1665   0.1730    0.1698  1779653  2525981
# 267    SPY  2/25/2021    0.2312   0.2230    0.2271  2395911  3228557
# 268    SPY  2/26/2021    0.2152   0.2095    0.2124  2628885  3315995
#
#      totalvol   calloi     putoi  comment    open      high       low   close  \
# ...

# %%
import datetime
format_str = '%m/%d/%Y'
df_merged['quotedate'] = df_merged['quotedate'].map(lambda x: datetime.datetime.strptime(x, format_str))

# %%
df_merged.to_csv('spy-c2.csv')

# %%
chunk1 = pd.read_csv('spy_data.csv')
chunk2 = pd.read_csv('spy-c2.csv')

# %%
chunk1.head()
# Out:
#    Unnamed: 0 UnderlyingSymbol  UnderlyingPrice Exchange        OptionSymbol  \
# 0      741721              SPY           324.12        *  SPY200203C00270000
# 1      741722              SPY           324.12        *  SPY200203P00270000
# 2      741723              SPY           324.12        *  SPY200203C00275000
# 3      741724              SPY           324.12        *  SPY200203P00275000
# 4      741725              SPY           324.12        *  SPY200203C00280000
#
#    OptionExt  Type  Expiration    DataDate  Strike  ...   Bid    Ask  Volume  \
# 0        NaN  call  02/03/2020  02/03/2020   270.0  ...  53.5  54.20       0
# 1        NaN   put  02/03/2020  02/03/2020   270.0  ...   0.0   0.01       0
# 2        NaN  call  02/03/2020  02/03/2020   275.0  ...  48.5  49.20       0
# 3        NaN   put  02/03/2020  02/03/2020   275.0  ...   0.0   0.01       1
# 4        NaN  call  02/03/2020  02/03/2020   280.0  ...  43.5  44.20       0
#
# ...

# %%
chunk1.shape
# Out:
# (2560346, 21)

# %%
chunk2.head()
# Out:
#    Unnamed: 0 symbol   quotedate  iv30call  iv30put  iv30mean  callvol  \
# 0           0    SPY  2020-02-03    0.1616   0.1649    0.1632   851840
# 1           1    SPY  2020-02-04    0.1453   0.1392    0.1422   836510
# 2           2    SPY  2020-02-05    0.1364   0.1280    0.1322  1104236
# 3           3    SPY  2020-02-06    0.1265   0.1274    0.1270   863736
# 4           4    SPY  2020-02-07    0.1318   0.1292    0.1305   944842
#
#     putvol  totalvol   calloi     putoi  comment    open      high     low  \
# 0  1828476   2680316  6418694  10882029      NaN  323.35  326.1600  323.22
# 1  1738239   2574749  6604106  10957636      NaN  328.07  330.0100  327.72
# 2  2065727   3169963  6685202  11123615      NaN  332.27  333.0900  330.67
# 3  1355895   2219631  6756780  11392538      NaN  333.91  334.1900  332.80
# 4  2136060   3080902  6842437  11608680      NaN  332.82  333.9941  331.60
#
#     close    volume  adjustedclose
# 0  324.12  63008919         324.12
# ...

# %%
chunk2 = chunk2.drop('Unnamed: 0', axis=1)

# %%
chunk2.head()
# Out:
#   symbol   quotedate  iv30call  iv30put  iv30mean  callvol   putvol  totalvol  \
# 0    SPY  2020-02-03    0.1616   0.1649    0.1632   851840  1828476   2680316
# 1    SPY  2020-02-04    0.1453   0.1392    0.1422   836510  1738239   2574749
# 2    SPY  2020-02-05    0.1364   0.1280    0.1322  1104236  2065727   3169963
# 3    SPY  2020-02-06    0.1265   0.1274    0.1270   863736  1355895   2219631
# 4    SPY  2020-02-07    0.1318   0.1292    0.1305   944842  2136060   3080902
#
#     calloi     putoi  comment    open      high     low   close    volume  \
# 0  6418694  10882029      NaN  323.35  326.1600  323.22  324.12  63008919
# 1  6604106  10957636      NaN  328.07  330.0100  327.72  329.06  56298908
# 2  6685202  11123615      NaN  332.27  333.0900  330.67  332.84  56474640
# 3  6756780  11392538      NaN  333.91  334.1900  332.80  333.93  45389314
# 4  6842437  11608680      NaN  332.82  333.9941  331.60  332.24  57535098
#
#    adjustedclose
# 0         324.12
# ...

# %%
chunk1['DataDate']
# Out:
# 0          02/03/2020
# 1          02/03/2020
# 2          02/03/2020
# 3          02/03/2020
# 4          02/03/2020
#               ...
# 2560341    02/26/2021
# 2560342    02/26/2021
# 2560343    02/26/2021
# 2560344    02/26/2021
# 2560345    02/26/2021
# Name: DataDate, Length: 2560346, dtype: object

# %%
import datetime
format_str = '%m/%d/%Y'
chunk1['DataDate'] = chunk1['DataDate'].map(lambda x: datetime.datetime.strptime(x, format_str))

# %%
chunk1['DataDate']
# Out:
# 0         2020-02-03
# 1         2020-02-03
# 2         2020-02-03
# 3         2020-02-03
# 4         2020-02-03
#              ...
# 2560341   2021-02-26
# 2560342   2021-02-26
# 2560343   2021-02-26
# 2560344   2021-02-26
# 2560345   2021-02-26
# Name: DataDate, Length: 2560346, dtype: datetime64[ns]

# %%
chunk2 = chunk2.set_index('quotedate')

# %%
big_list = []

for index, row in chunk1.iterrows():
    d = row['DataDate']
    temp = pd.concat([chunk1.loc[indemerx], chunk2.loc[d]])
    big_list.append(temp)
merged_chunk = pd.DataFrame(big_list)

# %%
chunk2['quotedate']
# Out:
# 0      2020-02-03
# 1      2020-02-04
# 2      2020-02-05
# 3      2020-02-06
# 4      2020-02-07
#           ...
# 264    2021-02-22
# 265    2021-02-23
# 266    2021-02-24
# 267    2021-02-25
# 268    2021-02-26
# Name: quotedate, Length: 269, dtype: object

# %%
format_str = '%Y-%m-%d'
chunk2['quotedate'] = chunk2['quotedate'].map(lambda x: datetime.datetime.strptime(x, format_str))

# %%
chunk2
# Out:
#      quotedate symbol  iv30call  iv30put  iv30mean  callvol   putvol  \
# 0   2020-02-03    SPY    0.1616   0.1649    0.1632   851840  1828476
# 1   2020-02-04    SPY    0.1453   0.1392    0.1422   836510  1738239
# 2   2020-02-05    SPY    0.1364   0.1280    0.1322  1104236  2065727
# 3   2020-02-06    SPY    0.1265   0.1274    0.1270   863736  1355895
# 4   2020-02-07    SPY    0.1318   0.1292    0.1305   944842  2136060
# ..         ...    ...       ...      ...       ...      ...      ...
# 264 2021-02-22    SPY    0.1832   0.1891    0.1861  1421348  2402597
# 265 2021-02-23    SPY    0.1794   0.1891    0.1842  1866016  2889660
# 266 2021-02-24    SPY    0.1665   0.1730    0.1698  1779653  2525981
# 267 2021-02-25    SPY    0.2312   0.2230    0.2271  2395911  3228557
# 268 2021-02-26    SPY    0.2152   0.2095    0.2124  2628885  3315995
#
#      totalvol   calloi     putoi  comment    open      high       low   close  \
# ...

# %%
chunk2['quotedate']
# Out:
# 0     2020-02-03
# 1     2020-02-04
# 2     2020-02-05
# 3     2020-02-06
# 4     2020-02-07
#          ...
# 264   2021-02-22
# 265   2021-02-23
# 266   2021-02-24
# 267   2021-02-25
# 268   2021-02-26
# Name: quotedate, Length: 269, dtype: datetime64[ns]

# %%
chunk1.iloc[1]['DataDate']
# Out:
# Timestamp('2020-02-03 00:00:00')

# %%
if chunk1.iloc[1]['DataDate'] == chunk2['quotedate'][0]:
    print('hi')
# Out:
# hi

# %%
chunk2 = chunk2.set_index('quotedate')
t = chunk1.iloc[1]['DataDate']
chunk2.loc[t]
# Out:
# Unnamed: 0              0
# symbol                SPY
# iv30call           0.1616
# iv30put            0.1649
# iv30mean           0.1632
# callvol            851840
# putvol            1828476
# totalvol          2680316
# calloi            6418694
# putoi            10882029
# comment               NaN
# open               323.35
# high               326.16
# low                323.22
# close              324.12
# volume           63008919
# adjustedclose      324.12
# Name: 2020-02-03 00:00:00, dtype: object

# %%
chunk2 = chunk2.reset_index()
chunk2.head()

# %%
chunk1 = chunk1[chunk1['DataDate'] != datetime.datetime.strptime('02/01/2021', '%m/%d/%Y')]

# %%
import datetime
chunk1 = chunk1[chunk1['DataDate'] != '02/01/2021']

# %%
chunk1.head()
# Out:
#    Unnamed: 0 UnderlyingSymbol  UnderlyingPrice Exchange        OptionSymbol  \
# 0      741721              SPY           324.12        *  SPY200203C00270000
# 1      741722              SPY           324.12        *  SPY200203P00270000
# 2      741723              SPY           324.12        *  SPY200203C00275000
# 3      741724              SPY           324.12        *  SPY200203P00275000
# 4      741725              SPY           324.12        *  SPY200203C00280000
#
#    OptionExt  Type  Expiration    DataDate  Strike  ...   Bid    Ask  Volume  \
# 0        NaN  call  02/03/2020  02/03/2020   270.0  ...  53.5  54.20       0
# 1        NaN   put  02/03/2020  02/03/2020   270.0  ...   0.0   0.01       0
# 2        NaN  call  02/03/2020  02/03/2020   275.0  ...  48.5  49.20       0
# 3        NaN   put  02/03/2020  02/03/2020   275.0  ...   0.0   0.01       1
# 4        NaN  call  02/03/2020  02/03/2020   280.0  ...  43.5  44.20       0
#
# ...

# %%
chunk1.shape
# Out:
# (2550706, 21)

# %%
chunk1  = chunk1.drop('Unnamed: 0', axis=1)

# %%
chunk2['quotedate']
# Out:
# 0      2020-02-03
# 1      2020-02-04
# 2      2020-02-05
# 3      2020-02-06
# 4      2020-02-07
#           ...
# 264    2021-02-22
# 265    2021-02-23
# 266    2021-02-24
# 267    2021-02-25
# 268    2021-02-26
# Name: quotedate, Length: 269, dtype: object

# %%
format_str = '%m/%d/%Y'
chunk1['DataDate'] = chunk1['DataDate'].map(lambda x: datetime.datetime.strptime(x, format_str))
format_str = '%Y-%m-%d'
chunk2['quotedate'] = chunk2['quotedate'].map(lambda x: datetime.datetime.strptime(x, format_str))

# %%
len(chunk1['DataDate'].unique())
# Out:
# 269

# %%
chunk2['quotedate'].shape
# Out:
# (269,)

# %%
big_list = []

for index, row in chunk1.iterrows():
    d = row['DataDate']
    temp = pd.concat([chunk1.loc[index], chunk2.loc[d]])
    big_list.append(temp)
merged_chunk = pd.DataFrame(big_list)

# %%
merged_chunk.shape
# Out:
# (2550706, 37)

# %%
merged_chunk.head()
# Out:
#   UnderlyingSymbol  UnderlyingPrice Exchange        OptionSymbol  OptionExt  \
# 0              SPY           324.12        *  SPY200203C00270000        NaN
# 1              SPY           324.12        *  SPY200203P00270000        NaN
# 2              SPY           324.12        *  SPY200203C00275000        NaN
# 3              SPY           324.12        *  SPY200203P00275000        NaN
# 4              SPY           324.12        *  SPY200203C00280000        NaN
#
#    Type  Expiration   DataDate  Strike   Last  ...  totalvol   calloi  \
# 0  call  02/03/2020 2020-02-03   270.0  51.70  ...   2680316  6418694
# 1   put  02/03/2020 2020-02-03   270.0   0.00  ...   2680316  6418694
# 2  call  02/03/2020 2020-02-03   275.0  49.01  ...   2680316  6418694
# 3   put  02/03/2020 2020-02-03   275.0   0.01  ...   2680316  6418694
# 4  call  02/03/2020 2020-02-03   280.0  42.76  ...   2680316  6418694
#
#       putoi  comment    open    high     low   close    volume adjustedclose
# ...

# %%
big_dict = {}
temp = merged_chunk.iloc[:10000, :]
temp
# Out:
#      UnderlyingSymbol  UnderlyingPrice Exchange        OptionSymbol  \
# 0                 SPY           324.12        *  SPY200203C00270000
# 1                 SPY           324.12        *  SPY200203P00270000
# 2                 SPY           324.12        *  SPY200203C00275000
# 3                 SPY           324.12        *  SPY200203P00275000
# 4                 SPY           324.12        *  SPY200203C00280000
# ...               ...              ...      ...                 ...
# 9995              SPY           329.06        *  SPY200304P00335000
# 9996              SPY           329.06        *  SPY200304C00336000
# 9997              SPY           329.06        *  SPY200304P00336000
# 9998              SPY           329.06        *  SPY200304C00337000
# 9999              SPY           329.06        *  SPY200304P00337000
#
#       OptionExt  Type  Expiration   DataDate  Strike   Last  ...  totalvol  \
# ...

# %%
temp
# Out:
#                      AKA UnderlyingSymbol  UnderlyingPrice Exchange  \
# 0     SPY200203C00270000              SPY           324.12        *
# 1     SPY200203P00270000              SPY           324.12        *
# 2     SPY200203C00275000              SPY           324.12        *
# 3     SPY200203P00275000              SPY           324.12        *
# 4     SPY200203C00280000              SPY           324.12        *
# ...                  ...              ...              ...      ...
# 9995  SPY200304P00335000              SPY           329.06        *
# 9996  SPY200304C00336000              SPY           329.06        *
# 9997  SPY200304P00336000              SPY           329.06        *
# 9998  SPY200304C00337000              SPY           329.06        *
# 9999  SPY200304P00337000              SPY           329.06        *
#
#             OptionSymbol  OptionExt  Type  Expiration  Strike   Last  ...  \
# 0     SPY200203C00270000        NaN  call  02/03/2020   270.0  51.70  ...
# ...

# %%
temp = temp.set_index('AKA')
temp_dict = {}
for index, row in temp.iterrows():
    if index not in temp_dict.keys():
        temp_dict[index] = {}
    d = row['DataDate']
    temp_dict[index][d] = list(zip(row.index, row))

# %%
for key, value in temp_dict.items():
    print(key + ': ' + str(len(value)))
# Out:
# SPY200203C00270000: 1
# SPY200203P00270000: 1
# SPY200203C00275000: 1
# SPY200203P00275000: 1
# SPY200203C00280000: 1
# SPY200203P00280000: 1
# SPY200203C00285000: 1
# SPY200203P00285000: 1
# SPY200203C00290000: 1
# SPY200203P00290000: 1
# SPY200203C00291000: 1
# SPY200203P00291000: 1
# SPY200203C00292000: 1
# SPY200203P00292000: 1
# SPY200203C00293000: 1
# SPY200203P00293000: 1
# SPY200203C00294000: 1
# SPY200203P00294000: 1
# SPY200203C00295000: 1
# SPY200203P00295000: 1
# SPY200203C00296000: 1
# SPY200203P00296000: 1
# SPY200203C00297000: 1
# SPY200203P00297000: 1
# SPY200203C00298000: 1
# SPY200203P00298000: 1
# SPY200203C00299000: 1
# SPY200203P00299000: 1
# SPY200203C00300000: 1
# SPY200203P00300000: 1
# SPY200203C00301000: 1
# SPY200203P00301000: 1
# SPY200203C00302000: 1
# SPY200203P00302000: 1
# SPY200203C00303000: 1
# SPY200203P00303000: 1
# SPY200203C00304000: 1
# SPY200203P00304000: 1
# SPY200203C00305000: 1
# SPY200203P00305000: 1
# SPY200203C00306000: 1
# ...

# %%
temp['DataDate'].unique()
# Out:
# array(['2020-02-03T00:00:00.000000000', '2020-02-04T00:00:00.000000000'],
#       dtype='datetime64[ns]')

# %%
pd.DataFrame(temp_dict)
# Out:
#                                            SPY200203C00270000  \
# 2020-02-03  [(UnderlyingSymbol, SPY), (UnderlyingPrice, 32...
# 2020-02-04                                                NaN
#
#                                            SPY200203P00270000  \
# 2020-02-03  [(UnderlyingSymbol, SPY), (UnderlyingPrice, 32...
# 2020-02-04                                                NaN
#
#                                            SPY200203C00275000  \
# 2020-02-03  [(UnderlyingSymbol, SPY), (UnderlyingPrice, 32...
# 2020-02-04                                                NaN
#
#                                            SPY200203P00275000  \
# 2020-02-03  [(UnderlyingSymbol, SPY), (UnderlyingPrice, 32...
# 2020-02-04                                                NaN
#
#                                            SPY200203C00280000  \
# 2020-02-03  [(UnderlyingSymbol, SPY), (UnderlyingPrice, 32...
# 2020-02-04                                                NaN
#
# ...

# %%
merged_chunk = merged_chunk.set_index('AKA')
big_dict = {}
for index, row in merged_chunk.iterrows():
    if index not in big_dict.keys():
        big_dict[index] = {}
    d = row['DataDate']
    big_dict[index][d] = list(zip(row.index, row))

# %%
dataset = pd.DataFrame(big_dict)

# %%
dataset.head()
# Out:
#                                            SPY200203C00270000  \
# 2020-02-03  [(UnderlyingSymbol, SPY), (UnderlyingPrice, 32...
# 2020-02-04                                                NaN
# 2020-02-05                                                NaN
# 2020-02-06                                                NaN
# 2020-02-07                                                NaN
#
#                                            SPY200203P00270000  \
# 2020-02-03  [(UnderlyingSymbol, SPY), (UnderlyingPrice, 32...
# 2020-02-04                                                NaN
# 2020-02-05                                                NaN
# 2020-02-06                                                NaN
# 2020-02-07                                                NaN
#
#                                            SPY200203C00275000  \
# 2020-02-03  [(UnderlyingSymbol, SPY), (UnderlyingPrice, 32...
# 2020-02-04                                                NaN
# ...

# %%
dataset.to_csv('daily_spy_track.csv')
